# %%
import os
import pandas as pd
import requests
import subprocess
from tqdm import tqdm
import os
import json
from elasticsearch import Elasticsearch

# %%
# Créer le répertoire pour stocker les fichiers téléchargés
download_dir = 'bano-data'
os.makedirs(download_dir, exist_ok=True)

def download_file(url, output_path):
    # Vérifier si le fichier existe déjà
    if os.path.exists(output_path):
        print(f"{output_path} already exists, skipping download.")
        return
    
    # Faire la requête pour récupérer la taille du fichier
    response = requests.get(url, stream=True)
    total_size = int(response.headers.get('content-length', 0))

    # Télécharger avec barre de progression
    with open(output_path, 'wb') as file, tqdm(
        desc=output_path,
        total=total_size,
        unit='B',
        unit_scale=True,
        unit_divisor=1024,
    ) as bar:
        for data in response.iter_content(chunk_size=1024):
            file.write(data)
            bar.update(len(data))

def main():
    base_url = "http://bano.openstreetmap.fr/data/"
    depts = list(range(1, 21)) + list(range(21, 96))

    for dept in depts:
        dept_str = f"{dept:02d}"
        print(f"Downloading bano department {dept_str}")
        url = f"{base_url}bano-{dept_str}.csv"
        output_path = os.path.join(download_dir, f"bano-{dept_str}.csv")
        download_file(url, output_path)

if __name__ == "__main__":
    main()
# Out:
# Downloading bano department 01
# bano-data\bano-01.csv already exists, skipping download.
# Downloading bano department 02
# bano-data\bano-02.csv already exists, skipping download.
# Downloading bano department 03
# bano-data\bano-03.csv already exists, skipping download.
# Downloading bano department 04
# bano-data\bano-04.csv already exists, skipping download.
# Downloading bano department 05
# bano-data\bano-05.csv already exists, skipping download.
# Downloading bano department 06
# bano-data\bano-06.csv already exists, skipping download.
# Downloading bano department 07
# bano-data\bano-07.csv already exists, skipping download.
# Downloading bano department 08
# bano-data\bano-08.csv already exists, skipping download.
# Downloading bano department 09
# bano-data\bano-09.csv already exists, skipping download.
# Downloading bano department 10
# bano-data\bano-10.csv already exists, skipping download.
# Downloading bano department 11
# bano-data\bano-11.csv already exists, skipping download.
# Downloading bano department 12
# bano-data\bano-12.csv already exists, skipping download.
# Downloading bano department 13
# bano-data\bano-13.csv already exists, skipping download.
# Downloading bano department 14
# bano-data\bano-14.csv already exists, skipping download.
# Downloading bano department 15
# bano-data\bano-15.csv already exists, skipping download.
# Downloading bano department 16
# bano-data\bano-16.csv already exists, skipping download.
# Downloading bano department 17
# bano-data\bano-17.csv already exists, skipping download.
# Downloading bano department 18
# bano-data\bano-18.csv already exists, skipping download.
# Downloading bano department 19
# bano-data\bano-19.csv already exists, skipping download.
# Downloading bano department 20
# bano-data\bano-20.csv already exists, skipping download.
# Downloading bano department 21
# bano-data\bano-21.csv already exists, skipping download.
# Downloading bano department 22
# bano-data\bano-22.csv already exists, skipping download.
# Downloading bano department 23
# bano-data\bano-23.csv already exists, skipping download.
# Downloading bano department 24
# bano-data\bano-24.csv already exists, skipping download.
# Downloading bano department 25
# bano-data\bano-25.csv already exists, skipping download.
# Downloading bano department 26
# bano-data\bano-26.csv already exists, skipping download.
# Downloading bano department 27
# bano-data\bano-27.csv already exists, skipping download.
# Downloading bano department 28
# bano-data\bano-28.csv already exists, skipping download.
# Downloading bano department 29
# bano-data\bano-29.csv already exists, skipping download.
# Downloading bano department 30
# bano-data\bano-30.csv already exists, skipping download.
# Downloading bano department 31
# bano-data\bano-31.csv already exists, skipping download.
# Downloading bano department 32
# bano-data\bano-32.csv already exists, skipping download.
# Downloading bano department 33
# bano-data\bano-33.csv already exists, skipping download.
# Downloading bano department 34
# bano-data\bano-34.csv already exists, skipping download.
# Downloading bano department 35
# bano-data\bano-35.csv already exists, skipping download.
# Downloading bano department 36
# bano-data\bano-36.csv already exists, skipping download.
# Downloading bano department 37
# bano-data\bano-37.csv already exists, skipping download.
# Downloading bano department 38
# bano-data\bano-38.csv already exists, skipping download.
# Downloading bano department 39
# bano-data\bano-39.csv already exists, skipping download.
# Downloading bano department 40
# bano-data\bano-40.csv already exists, skipping download.
# Downloading bano department 41
# bano-data\bano-41.csv already exists, skipping download.
# Downloading bano department 42
# bano-data\bano-42.csv already exists, skipping download.
# Downloading bano department 43
# bano-data\bano-43.csv already exists, skipping download.
# Downloading bano department 44
# bano-data\bano-44.csv already exists, skipping download.
# Downloading bano department 45
# bano-data\bano-45.csv already exists, skipping download.
# Downloading bano department 46
# bano-data\bano-46.csv already exists, skipping download.
# Downloading bano department 47
# bano-data\bano-47.csv already exists, skipping download.
# Downloading bano department 48
# bano-data\bano-48.csv already exists, skipping download.
# Downloading bano department 49
# bano-data\bano-49.csv already exists, skipping download.
# Downloading bano department 50
# bano-data\bano-50.csv already exists, skipping download.
# Downloading bano department 51
# bano-data\bano-51.csv already exists, skipping download.
# Downloading bano department 52
# bano-data\bano-52.csv already exists, skipping download.
# Downloading bano department 53
# bano-data\bano-53.csv already exists, skipping download.
# Downloading bano department 54
# bano-data\bano-54.csv already exists, skipping download.
# Downloading bano department 55
# bano-data\bano-55.csv already exists, skipping download.
# Downloading bano department 56
# bano-data\bano-56.csv already exists, skipping download.
# Downloading bano department 57
# bano-data\bano-57.csv already exists, skipping download.
# Downloading bano department 58
# bano-data\bano-58.csv already exists, skipping download.
# Downloading bano department 59
# bano-data\bano-59.csv already exists, skipping download.
# Downloading bano department 60
# bano-data\bano-60.csv already exists, skipping download.
# Downloading bano department 61
# bano-data\bano-61.csv already exists, skipping download.
# Downloading bano department 62
# bano-data\bano-62.csv already exists, skipping download.
# Downloading bano department 63
# bano-data\bano-63.csv already exists, skipping download.
# Downloading bano department 64
# bano-data\bano-64.csv already exists, skipping download.
# Downloading bano department 65
# bano-data\bano-65.csv already exists, skipping download.
# Downloading bano department 66
# bano-data\bano-66.csv already exists, skipping download.
# Downloading bano department 67
# bano-data\bano-67.csv already exists, skipping download.
# Downloading bano department 68
# bano-data\bano-68.csv already exists, skipping download.
# Downloading bano department 69
# bano-data\bano-69.csv already exists, skipping download.
# Downloading bano department 70
# bano-data\bano-70.csv already exists, skipping download.
# Downloading bano department 71
# bano-data\bano-71.csv already exists, skipping download.
# Downloading bano department 72
# bano-data\bano-72.csv already exists, skipping download.
# Downloading bano department 73
# bano-data\bano-73.csv already exists, skipping download.
# Downloading bano department 74
# bano-data\bano-74.csv already exists, skipping download.
# Downloading bano department 75
# bano-data\bano-75.csv already exists, skipping download.
# Downloading bano department 76
# bano-data\bano-76.csv already exists, skipping download.
# Downloading bano department 77
# bano-data\bano-77.csv already exists, skipping download.
# Downloading bano department 78
# bano-data\bano-78.csv already exists, skipping download.
# Downloading bano department 79
# bano-data\bano-79.csv already exists, skipping download.
# Downloading bano department 80
# bano-data\bano-80.csv already exists, skipping download.
# Downloading bano department 81
# bano-data\bano-81.csv already exists, skipping download.
# Downloading bano department 82
# bano-data\bano-82.csv already exists, skipping download.
# Downloading bano department 83
# bano-data\bano-83.csv already exists, skipping download.
# Downloading bano department 84
# bano-data\bano-84.csv already exists, skipping download.
# Downloading bano department 85
# bano-data\bano-85.csv already exists, skipping download.
# Downloading bano department 86
# bano-data\bano-86.csv already exists, skipping download.
# Downloading bano department 87
# bano-data\bano-87.csv already exists, skipping download.
# Downloading bano department 88
# bano-data\bano-88.csv already exists, skipping download.
# Downloading bano department 89
# bano-data\bano-89.csv already exists, skipping download.
# Downloading bano department 90
# bano-data\bano-90.csv already exists, skipping download.
# Downloading bano department 91
# bano-data\bano-91.csv already exists, skipping download.
# Downloading bano department 92
# bano-data\bano-92.csv already exists, skipping download.
# Downloading bano department 93
# bano-data\bano-93.csv already exists, skipping download.
# Downloading bano department 94
# bano-data\bano-94.csv already exists, skipping download.
# Downloading bano department 95
# bano-data\bano-95.csv already exists, skipping download.

# %%
# Lire la région à partir de la variable d'environnement
region = os.getenv('REGION', 'default_region')

# Charger le fichier CSV
df = pd.read_csv('bano-data/bano-01.csv', sep=',', header=None, names=[
    "id", "number", "street_name", "zipcode", "city", "source", "latitude", "longitude"
])

# Convertir les colonnes latitude et longitude en float
df['latitude'] = df['latitude'].astype(float)
df['longitude'] = df['longitude'].astype(float)

# Renommer les colonnes
df.rename(columns={
    "longitude": "location_lon",
    "latitude": "location_lat",
    "number": "address_number",
    "street_name": "address_street_name",
    "zipcode": "address_zipcode",
    "city": "address_city"
}, inplace=True)

# Ajouter la colonne 'region' avec la valeur de l'environnement REGION
df['region'] = region

# Supprimer les colonnes inutiles
df.drop(columns=["source"], inplace=True)

# Afficher un échantillon des données pour vérifier le traitement
print(df.head())

# Sauvegarder le dataframe traité dans un nouveau fichier CSV si besoin
df.to_csv('processed_data.csv', index=False)
# Out:
#               id address_number  address_street_name  address_zipcode  \
# 0  010010005-103            103  Impasse des Acacias             1400
# 1  010010005-104            104  Impasse des Acacias             1400
# 2   010010005-26             26  Impasse des Acacias             1400
# 3   010010005-30             30  Impasse des Acacias             1400
# 4   010010005-59             59  Impasse des Acacias             1400
#
#               address_city  location_lat  location_lon          region
# 0  L'Abergement-Clémenciat     46.147615      4.924047  default_region
# 1  L'Abergement-Clémenciat     46.147662      4.924207  default_region
# 2  L'Abergement-Clémenciat     46.146906      4.924205  default_region
# 3  L'Abergement-Clémenciat     46.147004      4.924469  default_region
# 4  L'Abergement-Clémenciat     46.147161      4.924281  default_region

# %%
# Connexion à Elasticsearch (ajustez l'URL si nécessaire)
es = Elasticsearch("http://localhost:9200")

# Charger le fichier de modèle (template) JSON
template_file = 'bano.json'
with open(template_file, 'r') as f:
    template = json.load(f)

# Nom de la région, récupéré depuis une variable d'environnement
region = os.getenv('REGION', 'default_region')

# Index Elasticsearch basé sur la région
index_name = f".bano-{region}"

# Nom du modèle (template)
template_name = "bano"

# Fonction pour créer ou mettre à jour le modèle (template)
def create_or_update_template(es_client, template_name, template_body):
    es_client.indices.put_template(name=template_name, body=template_body)

# Appliquer ou mettre à jour le modèle (template) sur Elasticsearch
create_or_update_template(es, template_name, template)

# Exemple de document à indexer
document = {
    "id": "12345",
    "address": {
        "number": 10,
        "street_name": "Rue de l'exemple",
        "zipcode": "75001",
        "city": "Paris"
    },
    "location": {
        "lat": 48.8566,
        "lon": 2.3522
    }
}

# Indexer le document avec le document_id basé sur l'ID du document
def index_document(es_client, index_name, document):
    document_id = document.get("id")
    es_client.index(index=index_name, id=document_id, body=document)

# Indexer le document dans Elasticsearch
index_document(es, index_name, document)

print(f"Document indexed in {index_name} with ID {document['id']}")
# Out:
# Document indexed in .bano-default_region with ID 12345
# C:\Users\GRETA\AppData\Local\Temp\ipykernel_8664\731838768.py:20: ElasticsearchWarning: Legacy index templates are deprecated in favor of composable templates.
#   es_client.indices.put_template(name=template_name, body=template_body)

# %%
import os
import subprocess
import requests

# Fonction pour importer une région dans Elasticsearch via Logstash
def import_region(region):
    # Exporter la région comme variable d'environnement (pour être utilisée par Logstash)
    os.environ['REGION'] = region  # Ici, region est directement passé par l'appel à import_region.
    
    # Fichier CSV pour la région donnée
    file_path = os.path.abspath(f'bano-data/bano-{region}.csv')
    
    # Vérifier si le fichier CSV existe
    if not os.path.exists(file_path):
        raise FileNotFoundError(f"Le fichier {file_path} est introuvable.")
    
    # Supprimer l'index dans Elasticsearch (équivalent du 'curl -XDELETE')
    es_url = f"http://localhost:9200/.bano-{region}?pretty"
    response = requests.delete(es_url)
    
    if response.status_code == 200:
        print(f"Deleted index .bano-{region} from Elasticsearch.")
    else:
        print(f"Failed to delete index .bano-{region}. Status: {response.status_code}")
    
    # Chemin vers Logstash
    logstash_command = [
        'C:/Users/GRETA/Desktop/logstash-8.15.1/bin/logstash.bat',
        '-f', 'bano-data.conf'
    ]
    
    # Exécuter Logstash avec le fichier de configuration
    with open(file_path, 'r') as file:
        # Envoyer les données du fichier à Logstash via la commande subprocess
        process = subprocess.Popen(logstash_command, stdin=file)
        process.communicate()

# Liste des départements à traiter
def process_departments():
    depts = [f"{i:02d}" for i in range(1, 20)] + [f"{i:02d}" for i in range(21, 96)]
    
    for dept in depts:
        print(f"Processing department {dept}")
        import_region(dept)

if __name__ == "__main__":
    process_departments()
# Out:
# Processing department 01
# Failed to delete index .bano-01. Status: 404
# Processing department 02
# Failed to delete index .bano-02. Status: 404
# Processing department 03
# Failed to delete index .bano-03. Status: 404
# Processing department 04
# Failed to delete index .bano-04. Status: 404
# Processing department 05
# Failed to delete index .bano-05. Status: 404
# Processing department 06
# Failed to delete index .bano-06. Status: 404
# Processing department 07
# Failed to delete index .bano-07. Status: 404
# Processing department 08
# Failed to delete index .bano-08. Status: 404
# Processing department 09
# Failed to delete index .bano-09. Status: 404
# Processing department 10
# Failed to delete index .bano-10. Status: 404
# Processing department 11
# Failed to delete index .bano-11. Status: 404
# Processing department 12
# Failed to delete index .bano-12. Status: 404
# Processing department 13
# Failed to delete index .bano-13. Status: 404
# Processing department 14
# Failed to delete index .bano-14. Status: 404
# Processing department 15
# Failed to delete index .bano-15. Status: 404
# Processing department 16
# Failed to delete index .bano-16. Status: 404
# Processing department 17
# Failed to delete index .bano-17. Status: 404
# Processing department 18
# Failed to delete index .bano-18. Status: 404
# Processing department 19
# Failed to delete index .bano-19. Status: 404
# Processing department 21
# Failed to delete index .bano-21. Status: 404
# Processing department 22
# Failed to delete index .bano-22. Status: 404
# Processing department 23
# Failed to delete index .bano-23. Status: 404
# Processing department 24
# Failed to delete index .bano-24. Status: 404
# Processing department 25
# Failed to delete index .bano-25. Status: 404
# Processing department 26
# Failed to delete index .bano-26. Status: 404
# Processing department 27
# Failed to delete index .bano-27. Status: 404
# Processing department 28
# Failed to delete index .bano-28. Status: 404
# Processing department 29
# Failed to delete index .bano-29. Status: 404
# Processing department 30
# Failed to delete index .bano-30. Status: 404
# Processing department 31
# Failed to delete index .bano-31. Status: 404
# Processing department 32
# Failed to delete index .bano-32. Status: 404
# Processing department 33
# Failed to delete index .bano-33. Status: 404
# Processing department 34
# Failed to delete index .bano-34. Status: 404
# Processing department 35
# Failed to delete index .bano-35. Status: 404
